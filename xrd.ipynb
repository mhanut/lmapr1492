# %% [raw]
# from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
# from pymatgen.io.cif import CifWriter
# from pymatgen.ext.matproj import MPRester
# from pymatgen.analysis.diffraction.core import AbstractDiffractionPatternCalculator
# from pymatgen.analysis.diffraction.xrd import XRDCalculator
# with MPRester("ittkwe9m4QMvQT1m") as m:
#
#
#     # Structure for material id
#     structure = m.get_structure_by_material_id("mp-924129")
#
# w = CifWriter(structure)
# w.write_file('mystructure.cif')

# %%
struct = SpacegroupAnalyzer(structure)
xrd = XRDCalculator(wavelength = 1.54060)
pattern= xrd.get_pattern(structure,scaled=True)
xrd.show_plot(structure,annotate_peaks= False,two_theta_range=[0,175])

# %% [markdown]
# # Pour le premier pic; on prends leur intensité, leur angle et leurs indices

# %%
theta1= pattern.x[0]
intensity1= pattern.y[0]
indices1= pattern.hkls[0]
print('Angle premier pic' + str(theta1))
print('Intensité premier pic : ' + str(intensity1))
print('Indices hkl premier pic :' + str(indices1))
print('--------------------------------------------------------------------------------------------------------')
# Out:
# Angle premier pic25.00684356021956
# Intensité premier pic : 16.404004096766478
# Indices hkl premier pic :[{'hkl': (1, 1, 1), 'multiplicity': 2}, {'hkl': (1, 0, 0), 'multiplicity': 6}]
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Pour le deuxième pic; on prends leur intensité, leur angle et leurs indices

# %%
theta2= pattern.x[1]
intensity2= pattern.y[1]
indices2= pattern.hkls[1]
print('Angle deuxième pic' + str(theta2))
print('Intensité deuxième pic : ' + str(intensity2))
print('Indices hkl deuxième pic :' + str(indices2))
print('--------------------------------------------------------------------------------------------------------')
# Out:
# Angle deuxième pic28.95387211081951
# Intensité deuxième pic : 37.297710972385275
# Indices hkl deuxième pic :[{'hkl': (1, 1, 0), 'multiplicity': 6}]
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Pour le troisième pic; on prends leur intensité, leur angle et leurs indices

# %%
theta3= pattern.x[2]
intensity3= pattern.y[2]
indices3= pattern.hkls[2]
print('Angle troisième pic' + str(theta3))
print('Intensité troisième pic : ' + str(intensity3))
print('Indices hkl troisième pic :' + str(indices3))
# Out:
# Angle troisième pic41.40793537432326
# Intensité troisième pic : 100.0
# Indices hkl troisième pic :[{'hkl': (2, 1, 1), 'multiplicity': 6}, {'hkl': (1, 0, -1), 'multiplicity': 6}]
